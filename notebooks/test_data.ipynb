# %%
from nntools.dataset import ImageDataset
from nntools import NNOpt
from pathlib import Path

# %%
root = Path('/usagers/clpla/data/classification/eyepacs/train/.images_cache/EYEPACS_train_split_train/image/').resolve()

dataset = ImageDataset(root, use_cache=False, cache_option=NNOpt.CACHE_DISK)

# %%
len(dataset)
# Out:
# 28101

# %%
_ = dataset.get_mosaic(36, shuffle=True, show=True, fig_size=0.5)
